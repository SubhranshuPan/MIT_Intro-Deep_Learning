# %%
import tensorflow as tf

# %%
def generate_model():
    model = tf.keras.Sequential([
        # first convolutional layer
        tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=2, strides=2),

        # second convolutional layer
        tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=2, strides=2),

        # fully connected classifier
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(1024, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax') # 10 outputs
    ])
    return model

# %%
model = generate_model()
model.build(input_shape=(None, 28, 28, 1)) # Assuming a common image input shape for demonstration
model.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3298649189.py in <cell line: 0>()
# ----> 1 model = generate_model()
#       2 model.build(input_shape=(None, 28, 28, 1)) # Assuming a common image input shape for demonstration
#       3 model.summary()
#
# /tmp/ipython-input-2206113881.py in generate_model()
#       2     model = tf.keras.Sequential([
#       3         # first convolutional layer
# ----> 4         tf.keras.layers.Conv2D(32, filter_size=3, activation='relu'),
#       5         tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
#       6
#
# TypeError: Conv2D.__init__() missing 1 required positional argument: 'kernel_size'
